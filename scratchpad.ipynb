# %%
# %sql
SELECT category, COUNT(*) FROM workspace.imdb_data_analysis.bronze_imdb_title_principals 
GROUP BY category
ORDER BY COUNT(*) DESC;

# %%
# %sql
SELECT COUNT(*) FROM workspace.imdb_data_analysis.dim_episode;
